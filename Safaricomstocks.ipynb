# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection, linear_model

# %%
df = pd.read_csv(r'D:\Kaggle\Stock Prices\SafaricomStockPrices.csv')
df
# Out:
#          Date   Open   High    Low   Close    Volume
# 0    12/20/23  13.50  13.80  13.50   13.50   6908500
# 1    12/19/23  13.90  13.90  13.40   13.50  11518300
# 2    12/18/23  14.00  14.00  13.50   13.85   5857300
# 3    12/15/23  14.40  14.45  13.70   14.10    753200
# 4    12/14/23  14.45  14.45  14.20   14.40   6830400
# ..        ...    ...    ...    ...     ...       ...
# 986  01/08/20  31.20  32.50  31.20   31.85   3474800
# 987  01/07/20  31.55  31.70  31.30   31.55   7754500
# 988  01/06/20  31.70  31.70  31.05   31.50   1901800
# 989  01/03/20  31.60  31.80  31.00   31.55    905000
# 990  01/02/20  31.60  31.60  31.00   31.30    349300
#
# [991 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991 entries, 0 to 990
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     991 non-null    object
#  1    Open    991 non-null    float64
#  2    High    991 non-null    float64
#  3    Low     991 non-null    float64
#  4    Close   991 non-null    float64
#  5    Volume  991 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 46.6+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  991.000000  991.000000  991.000000  991.000000  9.910000e+02
# mean    29.450404   29.786882   28.971241   29.328305  7.974927e+06
# std      8.644600    8.720817    8.634198    8.715844  1.131607e+07
# min     11.650000   12.000000   11.500000   11.650000  1.028000e+05
# 25%     24.225000   24.500000   23.775000   24.000000  2.434900e+06
# 50%     29.900000   30.000000   29.300000   29.800000  5.272400e+06
# 75%     36.975000   37.500000   36.350000   36.875000  1.010010e+07
# max     45.000000   45.250000   44.000000   44.950000  2.084859e+08

# %%
saf = df.drop(' Volume', axis=1)
plt.style.use("ggplot")
saf.plot(figsize=(10, 6))
plt.show()

# %%
# We will plot a Pairplot of the numerical features
sns.pairplot(df)
# Out:
# c:\Users\Victo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Victo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Victo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Victo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
num_col = [" Close", " Open", " Low", " High", " Volume"]
corr = df[num_col].corr()
corr
# Out:
#             Close      Open       Low      High    Volume
#  Close   1.000000  0.998623  0.999509  0.999225 -0.078112
#  Open    0.998623  1.000000  0.998608  0.998889 -0.074289
#  Low     0.999509  0.998608  1.000000  0.998553 -0.079381
#  High    0.999225  0.998889  0.998553  1.000000 -0.070192
#  Volume -0.078112 -0.074289 -0.079381 -0.070192  1.000000

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(corr, cmap="spring")
plt.show()

# %%
list_col = [' Open', ' Close', ' High', ' Low']
df[list_col].plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %%
df.groupby(['Date'])[' Open'].mean().plot()
plt. title('Open vs Date')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df[' Open'].plot(figsize= (10,6))
# Out:
# <Axes: >

# %%
df.groupby(['Date'])[' Close'].mean().plot()
plt.title('Close vs Date')
plt.show()

# %%
df[' Close'].plot(figsize=(10, 6))
# Out:
# <Axes: >

# %%
df.groupby(['Date'])[' High'].mean().plot()
plt.title('High vs Date')
plt.show()

# %%
df[' High'].plot(figsize=(10, 6))
# Out:
# <Axes: >

# %%
df.groupby(['Date'])[' Low'].mean().plot()
plt.title('Low vs Date')
plt.show()

# %%
df[' Low'].plot(figsize=(10, 6))
# Out:
# <Axes: >

# %%
df.groupby("Date")[" Volume"].mean().plot()
plt.title("Volume v Date")
# Out:
# Text(0.5, 1.0, 'Volume v Date')

# %%
df[' Volume'].plot()
# Out:
# <Axes: >

# %%
sns.lmplot(data=df, x= ' Open', y= ' Volume')
plt.show()
# Out:
# c:\Users\Victo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df, x= ' Close', y= ' Volume')
# Out:
# c:\Users\Victo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
saff = df.copy()
saff['Date']= pd.to_datetime(saff['Date'])
saff = saff.groupby('Date')[[' Open', ' Close', ' Low', ' High', ' Volume']].sum()
# Out:
# C:\Users\Victo\AppData\Local\Temp\ipykernel_13656\3035489300.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   saff['Date']= pd.to_datetime(saff['Date'])

# %%
# Visualize the stock's daily closing price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(saff[' Close'])
plt.title('Safaricom closing price')
plt.show()

# %%
price = (df[' High'] + df[' Low'])/2
month = pd.DatetimeIndex(df['Date']).month

# %%
data = pd.DataFrame({'Month' : month, 'Open': df[' Open'], 'High': df[' High'], 'Low' : df[' Low'], 'Close': df[' Close'], 'Volume': df[' Volume'], 'Price' : price})
data
# Out:
#      Month   Open   High    Low  Close    Volume   Price
# 0       12  13.50  13.80  13.50  13.50   6908500  13.650
# 1       12  13.90  13.90  13.40  13.50  11518300  13.650
# 2       12  14.00  14.00  13.50  13.85   5857300  13.750
# 3       12  14.40  14.45  13.70  14.10    753200  14.075
# 4       12  14.45  14.45  14.20  14.40   6830400  14.325
# ..     ...    ...    ...    ...    ...       ...     ...
# 986      1  31.20  32.50  31.20  31.85   3474800  31.850
# 987      1  31.55  31.70  31.30  31.55   7754500  31.500
# 988      1  31.70  31.70  31.05  31.50   1901800  31.375
# 989      1  31.60  31.80  31.00  31.55    905000  31.400
# 990      1  31.60  31.60  31.00  31.30    349300  31.300
#
# [991 rows x 7 columns]

# %%
X = data.drop('Price', axis = 1)
y = data['Price']

# %%
from sklearn import linear_model, model_selection

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X,y, test_size = 0.20)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
X_test.shape, y_test.shape
# Out:
# ((199, 6), (199,))

# %%
y_pred
# Out:
# array([30.9  , 24.7  , 37.4  , 25.05 , 34.55 , 25.025, 40.25 , 14.25 ,
#        23.75 , 36.6  , 31.   , 41.075, 30.325, 17.125, 31.8  , 21.5  ,
#        21.925, 24.5  , 23.475, 29.25 , 36.75 , 27.05 , 13.575, 15.2  ,
#        18.65 , 41.6  , 40.3  , 29.775, 35.875, 41.025, 29.975, 31.4  ,
#        13.7  , 24.05 , 36.525, 27.4  , 15.95 , 32.025, 41.625, 14.775,
#        35.25 , 42.25 , 39.425, 25.5  , 22.5  , 15.1  , 38.5  , 23.5  ,
#        40.9  , 31.25 , 41.275, 17.5  , 42.7  , 16.7  , 22.325, 36.2  ,
#        39.025, 23.425, 35.425, 34.25 , 41.1  , 39.075, 28.9  , 24.55 ,
#        28.575, 40.325, 29.825, 35.   , 27.975, 25.45 , 28.9  , 17.8  ,
#        40.95 , 31.95 , 42.75 , 14.325, 29.5  , 27.9  , 27.1  , 28.85 ,
#        37.95 , 30.325, 16.95 , 30.35 , 41.8  , 43.025, 37.75 , 24.75 ,
#        42.725, 38.625, 28.225, 16.7  , 37.4  , 23.65 , 28.125, 17.225,
#        26.225, 21.425, 42.95 , 30.65 , 42.55 , 15.725, 37.5  , 34.025,
# ...

# %%
y_test
# Out:
# 398    30.900
# 265    24.700
# 466    37.400
# 284    25.050
# 737    34.550
#         ...
# 429    35.475
# 529    41.750
# 68     15.750
# 986    31.850
# 809    29.950
# Name: Price, Length: 199, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
Regressor = RandomForestRegressor()
Regressor.fit(X_train, y_train)
ypred = Regressor.predict(X_test)
print(f'Train Accuracy {round(Regressor.score(X_train, y_train)* 100,2)}%')
print(f'Test Accuracy {round(Regressor.score(X_test, y_test)* 100,2)}%')
# Out:
# Train Accuracy 100.0%
# Test Accuracy 99.99%

# %%
ypred
# Out:
# array([30.71425, 24.74025, 37.378  , 24.95075, 34.51125, 24.96575,
#        40.142  , 14.0945 , 24.04125, 36.5    , 31.031  , 41.09875,
#        30.34575, 17.07325, 31.827  , 21.4785 , 21.7345 , 24.501  ,
#        23.58975, 29.32875, 36.68675, 27.04425, 13.57325, 15.22125,
#        18.64325, 41.59425, 40.3525 , 29.77725, 35.8975 , 41.11925,
#        29.99375, 31.4315 , 13.682  , 24.06475, 36.52175, 27.4475 ,
#        15.92275, 31.911  , 41.6315 , 14.71975, 35.05225, 42.0995 ,
#        39.4825 , 25.05075, 22.91175, 15.10975, 38.4815 , 23.492  ,
#        40.93275, 31.7075 , 41.31925, 17.56025, 42.71   , 16.7285 ,
#        22.57975, 36.219  , 38.939  , 23.36175, 35.47325, 34.2475 ,
#        41.1065 , 38.93925, 28.86275, 24.47975, 28.58225, 40.4335 ,
#        29.8175 , 34.9505 , 28.0115 , 25.47725, 29.04125, 17.654  ,
#        41.003  , 31.883  , 42.80675, 14.36275, 29.50575, 27.73025,
#        27.07075, 28.8045 , 37.9905 , 30.27725, 16.8665 , 30.16125,
# ...

# %%
y_test
# Out:
# 398    30.900
# 265    24.700
# 466    37.400
# 284    25.050
# 737    34.550
#         ...
# 429    35.475
# 529    41.750
# 68     15.750
# 986    31.850
# 809    29.950
# Name: Price, Length: 199, dtype: float64
